# %%
import pandas as pd

# %%
data = pd.read_csv('data/alturas-pesos-train.csv')

# %%
data
# Out:
#       Genero  Peso  Altura
# 0      Mujer    54     155
# 1     Hombre    94     189
# 2     Hombre    91     174
# 3      Mujer    60     167
# 4      Mujer    72     170
# 5      Mujer    58     157
# 6      Mujer    67     165
# 7      Mujer    70     174
# 8     Hombre    69     167
# 9     Hombre    87     178
# 10     Mujer    62     159
# 11    Hombre    78     166
# 12    Hombre    87     169
# 13     Mujer    74     165
# 14     Mujer    63     162
# 15     Mujer    60     164
# 16     Mujer    62     158
# 17     Mujer    62     164
# 18    Hombre    97     185
# 19     Mujer    63     161
# 20     Mujer    66     157
# 21     Mujer    53     162
# 22     Mujer    55     161
# 23     Mujer    58     160
# 24     Mujer    73     169
# 25     Mujer    38     142
# 26    Hombre    78     174
# 27     Mujer    52     151
# 28    Hombre    88     178
# 29    Hombre    86     179
# ...      ...   ...     ...
# 7970  Hombre    89     182
# 7971  Hombre    70     170
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
data[['Altura']].values
# Out:
# array([[155],
#        [189],
#        [174],
#        ...,
#        [163],
#        [175],
#        [171]])

# %%
model.fit(data[['Altura']].values, data[['Peso']].values)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(model.intercept_, model.coef_)
# Out:
# [-158.39556463] [[1.37500931]]

# %%
model.predict(171)
# Out:
# array([[76.73102742]])
