# %%
import numpy as np

# %%
imagenes = np.load('images/cats.npy')

# %%
imagenes.shape
# Out:
# (5, 177, 284, 3)

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(imagenes[2], cmap='gray')
plt.show()

# %%
imagenes.shape
# Out:
# (5, 177, 284, 3)

# %%
plt.imshow(imagenes[1, :, :, :], cmap='gray')
plt.show()
