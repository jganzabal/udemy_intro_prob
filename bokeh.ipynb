# %%
# Estos dos comandos evitan que haya que hacer reload cada vez que se modifica un paquete
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data/alturas-pesos-mils-train.csv')

# %%
from sklearn.preprocessing import MinMaxScaler
normalizeData = MinMaxScaler()
X_train  = normalizeData.fit_transform(data[['Peso', 'Altura']].values)

# %%
data_hombres = normalizeData.transform(data.loc[data['Genero']=='Hombre'][['Peso','Altura']].values)
data_mujeres = normalizeData.transform(data.loc[data['Genero']=='Mujer'][['Peso','Altura']].values)

# %%
from bokeh.plotting import figure
from bokeh.io import output_notebook, push_notebook, show, curdoc
import time

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3cf26f9c-7086-40d8-a5cb-776cf2031b4c">Loading BokehJS ...</span>
#     </div>

# %%
plot = figure(plot_width=400, plot_height=400)
h = plot.circle(data_hombres[:,0], data_hombres[:,1]) #size=2, color="red", alpha=0.5

t= show(plot, notebook_handle=True)
# Out:
#   <div class="bk-root" id="f9525900-daf7-45e0-9e92-10bfc6b1183d"></div>

# %%
# Update the plot title in the earlier cell
plot.circle(data_mujeres[:,0], data_mujeres[:,1], size=2, color="blue", alpha=0.5)
#plot.circle(data_mujeres[:,0], data_mujeres[:,1])
push_notebook(handle=t)

# %%
from ipywidgets import interact
import numpy as np

from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3cae18c8-3854-4046-9604-ca154c8446f4">Loading BokehJS ...</span>
#     </div>

# %%
x = np.linspace(0, 2*np.pi, 2000)
y = np.sin(x)

# %%
p = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-5,5))
r = p.line(x, y, color="#2222aa", line_width=3)

# %%
def update(f, w=1, A=1, phi=0):
    if   f == "sin": func = np.sin
    elif f == "cos": func = np.cos
    elif f == "tan": func = np.tan
    r.data_source.data['y'] = A * func(w * x + phi)
    push_notebook()

# %%
show(p, notebook_handle=True)
# Out:
#   <div class="bk-root" id="57a6a285-9176-4ab3-b893-32a86411867a"></div>
# <p><code>&lt;Bokeh Notebook handle for <strong>In[13]</strong>&gt;</code></p>

# %%
interact(update, f=["sin", "cos", "tan"], w=(0,100), A=(1,5), phi=(0, 20, 0.1))
# Out:
# interactive(children=(Dropdown(description='f', options=('sin', 'cos', 'tan'), value='sin'), IntSlider(value=1…
# <function __main__.update(f, w=1, A=1, phi=0)>
